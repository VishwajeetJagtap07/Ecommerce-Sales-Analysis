# %%
import pandas as pd

df = pd.read_csv("cleaned_superstore.csv")
df.head()
# Out:
#    Order ID  Order Date   Ship Date Customer Name      Segment Region  \
# 0  ORD-1000  2023-01-01  2023-01-03    Customer 0  Home Office  South
# 1  ORD-1001  2023-01-02  2023-01-04    Customer 1     Consumer   East
# 2  ORD-1002  2023-01-03  2023-01-05    Customer 2  Home Office   West
# 3  ORD-1003  2023-01-04  2023-01-06    Customer 3  Home Office   East
# 4  ORD-1004  2023-01-05  2023-01-07    Customer 4     Consumer   West
#
#      Category   Sales  Quantity  Discount  Profit  Year  Month  Profit Margin
# 0   Furniture  690.15         1      0.16   42.29  2023      1       0.061277
# 1   Furniture  446.86         5      0.02   43.27  2023      1       0.096831
# 2  Technology  713.45         4      0.07  206.26  2023      1       0.289102
# 3   Furniture  406.56         8      0.16   37.76  2023      1       0.092877
# 4  Technology  334.63         1      0.13  171.58  2023      1       0.512745

# %%
df.describe()
# Out:
#             Sales    Quantity    Discount      Profit    Year       Month  \
# count  200.000000  200.000000  200.000000  200.000000   200.0  200.000000
# mean   560.137500    5.020000    0.154700  130.624650  2023.0    3.840000
# std    254.252904    2.616069    0.081727  104.922653     0.0    1.926906
# min    112.300000    1.000000    0.000000  -49.920000  2023.0    1.000000
# 25%    341.192500    3.000000    0.090000   44.935000  2023.0    2.000000
# 50%    555.170000    5.000000    0.160000  132.865000  2023.0    4.000000
# 75%    767.607500    7.000000    0.230000  216.700000  2023.0    5.000000
# max    996.340000    9.000000    0.300000  299.770000  2023.0    7.000000
#
#        Profit Margin
# count     200.000000
# mean        0.332184
# std         0.419177
# min        -0.236320
# 25%         0.077692
# 50%         0.234946
# 75%         0.387226
# max         2.140904

# %%
df['Category'].value_counts()
df['Region'].value_counts()
df['Segment'].value_counts()
# Out:
# Segment
# Home Office    73
# Consumer       66
# Corporate      61
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['Sales'])
plt.show()

# %%
sns.barplot(x='Category', y='Sales', data=df)
plt.show()

# %%
sns.barplot(x='Region', y='Sales', data=df)
plt.show()

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()

monthly_sales.plot()
plt.show()

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         39431.91
# Furniture          38766.25
# Office Supplies    33829.34
# Name: Sales, dtype: float64

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    26595.95
# East       23832.98
# South      36996.80
# West       24601.77
# Name: Sales, dtype: float64

# %%
df.groupby('Month')['Sales'].sum()
# Out:
# Month
# 1    17004.89
# 2    17752.86
# 3    18031.52
# 4    16114.85
# 5    15639.23
# 6    15173.11
# 7    12311.04
# Name: Sales, dtype: float64

# %%
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture          8607.07
# Office Supplies    7519.02
# Technology         9998.84
# Name: Profit, dtype: float64

# %%
sns.scatterplot(x='Discount', y='Profit', data=df)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
